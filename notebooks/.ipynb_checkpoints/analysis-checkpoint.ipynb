# %%
# %% CELL 1 — IMPORTS AND DATA LOADING
"""
Load the merged Transport_Data database and define constants, gas pairs,
and helper structures used throughout the notebook.
"""

import pandas as pd
import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import warnings
warnings.filterwarnings("ignore")

plt.rcParams.update({
    "font.family": "DejaVu Sans",
    "font.size": 11,
    "axes.linewidth": 1.2,
    "xtick.major.width": 1.0,
    "ytick.major.width": 1.0,
    "xtick.direction": "in",
    "ytick.direction": "in",
    "figure.dpi": 150,
    "savefig.dpi": 300,
    "axes.spines.top": False,
    "axes.spines.right": False,
})

R = 8.314e-3  # kJ/(mol·K)

GAS_PAIRS = {
    "O2/N2":   {"A": "O2",  "B": "N2",  "label": r"O$_2$/N$_2$"},
    "CO2/N2":  {"A": "CO2", "B": "N2",  "label": r"CO$_2$/N$_2$"},
    "CO2/CH4": {"A": "CO2", "B": "CH4", "label": r"CO$_2$/CH$_4$"},
}

T_REF = 298.15  # 25 °C — reference temperature for αE calculation

df = pd.read_excel("../data/Transport_Data_Merged.xlsx")

for col in ["alpha_D", "alpha_E", "alpha_S", "alpha_P"]:
    df[col] = pd.to_numeric(df[col], errors="coerce")

MATERIAL_ALIASES = {
    "4A Zeolite": "Zeolite 4A",
    "Carbon Molecular Sieve (CMS)": "CMS",
    "Upper bound polypyrrolone (6FDA-TADPO)": "6FDA-TADPO",
    "Matrimid+Trip-H_20": "Matrimid + Trip-H_20",
    "Matrimid+Trip-NH2_20": "Matrimid + Trip-NH2_20",
    "Matrimid+Trip-NO2_20": "Matrimid + Trip-NO2_20",
    "Matrimid+Trip-SO3H_20": "Matrimid + Trip-SO3H_20",
}
df["Material"] = df["Material"].replace(MATERIAL_ALIASES)

print(f"Loaded {len(df)} rows, {df['Material'].nunique()} unique materials (after alias normalization)")
print(f"Columns: {len(df.columns)}")
# Out:
# Loaded 1525 rows, 68 unique materials (after alias normalization)
# Columns: 66

# %%
# %% CELL 2 — DATA AUDIT: EXISTING SELECTIVITY DECOMPOSITION
"""
For each gas pair, identify materials that ALREADY have αE and αS
stored in the dataset (from literature or prior calculations).
These form the baseline — no computation needed.
"""

existing = {}

for pair, info in GAS_PAIRS.items():
    sel = df[df["Gas"] == pair].copy()

    has_E_and_S = sel[sel["alpha_E"].notna() & sel["alpha_S"].notna()]
    mats = has_E_and_S.groupby("Material").first().reset_index()
    existing[pair] = mats[["Material", "alpha_D", "alpha_E", "alpha_S"]].copy()
    existing[pair]["source"] = "existing"
    existing[pair]["pair"] = pair

    print(f"\n{'='*60}")
    print(f"  {pair}:  {len(mats)} materials with αE + αS already available")
    print(f"{'='*60}")
    for _, r in mats.iterrows():
        aD = f"{r['alpha_D']:.3f}" if pd.notna(r["alpha_D"]) else "—"
        aE = f"{r['alpha_E']:.3f}" if pd.notna(r["alpha_E"]) else "—"
        aS = f"{r['alpha_S']:.4f}" if pd.notna(r["alpha_S"]) else "—"
        print(f"    {r['Material']:45s}  αD={aD:>10s}  αE={aE:>10s}  αS={aS:>10s}")
# Out:
# ...
#   O2/N2:  32 materials with αE + αS already available
# ...
#     6FDA-6FmDA                                     αD=     5.000  αE=    50.400  αS=    0.1000
#     6FDA-6FpDA                                     αD=     4.100  αE=     4.300  αS=    0.9000
#     6FDA-TAB                                       αD=     4.000  αE=     3.000  αS=    1.4000
#     6FDA-TADPO                                     αD=     5.100  αE=     4.350  αS=    1.2000
#     6FDA/PMDA(10/90)-TAB                           αD=     8.700  αE=    78.000  αS=    0.1100
#     6FDA/PMDA(25/75)-TAB                           αD=     7.800  αE=    33.000  αS=    0.2400
#     6FDA/PMDA(50/50)-TAB                           αD=     4.200  αE=     1.800  αS=    2.3000
#     AD60x + F4 MIL140                              αD=         —  αE=     4.900  αS=    0.4700
#     AO-PIM-OCF_MeOH_3rd_172d_dT                    αD=         —  αE=   118.892  αS=    0.0565
# ...

# %%
# %% CELL 3 — ROUTE 1: DIRECT αE FROM ED PAIRS
"""
For materials that have activation energy of diffusion (ED) for BOTH gases
in a pair but lack αE/αS, compute:

    αE = exp[ −(ED_A − ED_B) / (R · T_ref) ]

Then if αD is available (from D ratio or existing data), derive:

    αS = αD / αE

This is the fastest recovery route — no fitting needed.
"""

def get_ED(material, gas):
    """Retrieve ED [kJ/mol] for a material/gas from the dataset."""
    rows = df[(df["Material"] == material) & (df["Gas"] == gas) & df["ED_kJmol"].notna()]
    if len(rows) == 0:
        return np.nan
    return rows["ED_kJmol"].values[0]


def get_alpha_D_from_data(material, pair, gasA, gasB):
    """Try to get αD from existing selectivity rows or compute from D ratio."""
    sel = df[(df["Material"] == material) & (df["Gas"] == pair) & df["alpha_D"].notna()]
    if len(sel) > 0:
        vals = pd.to_numeric(sel["alpha_D"], errors="coerce").dropna()
        if len(vals) > 0:
            return vals.values[0]

    d_A = df[(df["Material"] == material) & (df["Gas"] == gasA) & df["D_1e8_cm2s"].notna()]
    d_B = df[(df["Material"] == material) & (df["Gas"] == gasB) & df["D_1e8_cm2s"].notna()]
    if len(d_A) > 0 and len(d_B) > 0:
        return d_A["D_1e8_cm2s"].values[0] / d_B["D_1e8_cm2s"].values[0]
    return np.nan


from_ED = {}

for pair, info in GAS_PAIRS.items():
    gasA, gasB = info["A"], info["B"]

    ed_A = df[(df["Gas"] == gasA) & df["ED_kJmol"].notna()][["Material", "ED_kJmol"]].drop_duplicates("Material")
    ed_B = df[(df["Gas"] == gasB) & df["ED_kJmol"].notna()][["Material", "ED_kJmol"]].drop_duplicates("Material")
    ed_A.columns = ["Material", "ED_A"]
    ed_B.columns = ["Material", "ED_B"]
    merged = ed_A.merge(ed_B, on="Material")

    already_done = set(existing[pair]["Material"].unique())
    merged = merged[~merged["Material"].isin(already_done)]

    rows = []
    for _, r in merged.iterrows():
        delta_ED = r["ED_A"] - r["ED_B"]
        alpha_E = np.exp(-delta_ED / (R * T_REF))
        alpha_D = get_alpha_D_from_data(r["Material"], pair, gasA, gasB)
        alpha_S = alpha_D / alpha_E if (pd.notna(alpha_D) and alpha_E != 0) else np.nan
        rows.append({
            "Material": r["Material"],
            "ED_A": r["ED_A"],
            "ED_B": r["ED_B"],
            "delta_ED": delta_ED,
            "alpha_E": alpha_E,
            "alpha_D": alpha_D,
            "alpha_S": alpha_S,
            "source": "from_ED",
            "pair": pair,
        })

    result = pd.DataFrame(rows)
    from_ED[pair] = result

    print(f"\n{'='*60}")
    print(f"  {pair}:  {len(result)} materials recovered via ED")
    print(f"  (T_ref = {T_REF - 273.15:.0f} °C,  ΔED = ED({gasA}) − ED({gasB}))")
    print(f"{'='*60}")
    for _, r in result.iterrows():
        aD = f"{r['alpha_D']:.3f}" if pd.notna(r["alpha_D"]) else "—"
        aE = f"{r['alpha_E']:.3f}" if pd.notna(r["alpha_E"]) else "—"
        aS = f"{r['alpha_S']:.4f}" if pd.notna(r["alpha_S"]) else "—"
        print(f"    {r['Material']:45s}  ΔED={r['delta_ED']:+6.2f}  αE={aE:>10s}  αD={aD:>10s}  αS={aS:>10s}")
# Out:
# ...
#   O2/N2:  6 materials recovered via ED
#   (T_ref = 25 °C,  ΔED = ED(O2) − ED(N2))
# ...
#     Precursor (6FDA/DETDA:DABA)                    ΔED= -1.90  αE=     2.152  αD=         —  αS=         —
#     550°C-CMS                                      ΔED= -1.80  αE=     2.067  αD=         —  αS=         —
#     800°C-CMS                                      ΔED= -0.90  αE=     1.438  αD=         —  αS=         —
#     800°C-precrosslinked-CMS                       ΔED= -0.60  αE=     1.274  αD=         —  αS=         —
#     PTMSP                                          ΔED= +0.00  αE=     1.000  αD=     1.333  αS=    1.3333
#     PIM-OCF_CJ205_MeOH_193d_25C                    ΔED= -2.10  αE=     2.329  αD=     5.723  αS=    2.4571
#
# ...
#   CO2/N2:  6 materials recovered via ED
#   (T_ref = 25 °C,  ΔED = ED(CO2) − ED(N2))
# ...
#     Precursor (6FDA/DETDA:DABA)                    ΔED= -2.00  αE=     2.241  αD=         —  αS=         —
# ...

# %%
# %% CELL 4 — ROUTE 2: ARRHENIUS FITTING
"""
For materials with diffusivity D at ≥3 temperatures for both gases in a pair,
perform Arrhenius regression:

    ln(D) = ln(D₀) − ED / (R·T)

This yields ED and D₀ for each gas. Then:
    αE = exp[ −(ED_A − ED_B) / (R·T_ref) ]
    αS = D₀_A / D₀_B

Diagnostic plots show the quality of each fit.
"""

def arrhenius_fit(material, gas):
    """
    Fit ln(D) vs 1/T for a given material and gas.
    Returns (ED_kJmol, D0, R2, T_array, D_array) or None if insufficient data.
    D is in units of 1e-8 cm²/s throughout.
    """
    rows = df[
        (df["Material"] == material) &
        (df["Gas"] == gas) &
        df["D_1e8_cm2s"].notna() &
        df["T_C"].notna()
    ].copy()

    rows["T_C"] = pd.to_numeric(rows["T_C"], errors="coerce")
    rows = rows.dropna(subset=["T_C", "D_1e8_cm2s"])
    rows = rows[rows["D_1e8_cm2s"] > 0]

    if len(rows) < 3:
        return None

    T_K = rows["T_C"].values + 273.15
    D = rows["D_1e8_cm2s"].values
    inv_T = 1.0 / T_K
    ln_D = np.log(D)

    slope, intercept, r_value, _, _ = linregress(inv_T, ln_D)
    ED = -slope * R  # kJ/mol (since slope = -ED/R with R in kJ/(mol·K))
    D0 = np.exp(intercept)

    return {
        "ED": ED,
        "D0": D0,
        "R2": r_value**2,
        "T_C": rows["T_C"].values,
        "T_K": T_K,
        "D": D,
        "inv_T": inv_T,
        "ln_D": ln_D,
        "slope": slope,
        "intercept": intercept,
    }


def get_fittable_materials(gasA, gasB, min_temps=3):
    """Find materials with D at ≥min_temps for BOTH gases."""
    fittable = []
    for gas in [gasA, gasB]:
        rows = df[(df["Gas"] == gas) & df["D_1e8_cm2s"].notna() & df["T_C"].notna()]
        rows = rows.copy()
        rows["T_C"] = pd.to_numeric(rows["T_C"], errors="coerce")
        rows = rows.dropna(subset=["T_C"])
        counts = rows.groupby("Material")["T_C"].nunique()
        mats = set(counts[counts >= min_temps].index)
        fittable.append(mats)
    return fittable[0] & fittable[1]


arrhenius_results = {}

for pair, info in GAS_PAIRS.items():
    gasA, gasB = info["A"], info["B"]

    already_done = set(existing[pair]["Material"].unique())
    if pair in from_ED:
        already_done |= set(from_ED[pair]["Material"].unique())

    fittable = get_fittable_materials(gasA, gasB) - already_done

    print(f"\n{'='*60}")
    print(f"  {pair}:  {len(fittable)} materials for Arrhenius fitting")
    print(f"{'='*60}")

    if len(fittable) == 0:
        arrhenius_results[pair] = pd.DataFrame()
        print("    No additional materials to fit.")
        continue

    fit_data = []
    plot_materials = sorted(fittable)

    n_mats = len(plot_materials)
    n_cols = min(4, n_mats)
    n_rows_plot = int(np.ceil(n_mats / n_cols))

    fig, axes = plt.subplots(
        n_rows_plot, n_cols,
        figsize=(4.2 * n_cols, 3.5 * n_rows_plot),
        squeeze=False,
    )

    colors = {"O2": "#2196F3", "N2": "#4CAF50", "CO2": "#E91E63", "CH4": "#FF9800"}

    for idx, mat in enumerate(plot_materials):
        ax = axes[idx // n_cols][idx % n_cols]

        fitA = arrhenius_fit(mat, gasA)
        fitB = arrhenius_fit(mat, gasB)

        if fitA is None or fitB is None:
            ax.set_title(mat, fontsize=9, fontweight="bold")
            ax.text(0.5, 0.5, "Insufficient data", ha="center", va="center", transform=ax.transAxes, fontsize=9)
            continue

        delta_ED = fitA["ED"] - fitB["ED"]
        alpha_E = np.exp(-delta_ED / (R * T_REF))
        alpha_S = fitA["D0"] / fitB["D0"]
        alpha_D = alpha_E * alpha_S

        fit_data.append({
            "Material": mat,
            "ED_A": fitA["ED"],
            "ED_B": fitB["ED"],
            "D0_A": fitA["D0"],
            "D0_B": fitB["D0"],
            "R2_A": fitA["R2"],
            "R2_B": fitB["R2"],
            "delta_ED": delta_ED,
            "alpha_E": alpha_E,
            "alpha_S": alpha_S,
            "alpha_D": alpha_D,
            "source": "arrhenius",
            "pair": pair,
        })

        for gas, fit, marker in [(gasA, fitA, "o"), (gasB, fitB, "s")]:
            inv_T_fit = np.linspace(fit["inv_T"].min() * 0.98, fit["inv_T"].max() * 1.02, 50)
            ln_D_fit = fit["slope"] * inv_T_fit + fit["intercept"]

            ax.plot(
                fit["inv_T"] * 1000, fit["ln_D"],
                marker=marker, ls="none", ms=6, color=colors.get(gas, "#666"),
                label=f"{gas}  R²={fit['R2']:.4f}", zorder=3,
            )
            ax.plot(
                inv_T_fit * 1000, ln_D_fit,
                ls="--", lw=1.2, color=colors.get(gas, "#666"), alpha=0.7,
            )

        ax.set_title(mat, fontsize=9, fontweight="bold")
        ax.set_xlabel("1000/T  [K⁻¹]", fontsize=8)
        ax.set_ylabel("ln(D)  [D in 10⁻⁸ cm²/s]", fontsize=8)
        ax.legend(fontsize=7, framealpha=0.8, loc="best")
        ax.tick_params(labelsize=8)

    for idx in range(n_mats, n_rows_plot * n_cols):
        axes[idx // n_cols][idx % n_cols].axis("off")

    fig.suptitle(
        f"Arrhenius Fits — {GAS_PAIRS[pair]['label']} separation",
        fontsize=13, fontweight="bold", y=1.01,
    )
    plt.tight_layout()
    plt.show()

    result = pd.DataFrame(fit_data)
    arrhenius_results[pair] = result

    print(f"\n  {'Material':45s}  {'ED_A':>7s}  {'ED_B':>7s}  {'R²_A':>6s}  {'R²_B':>6s}  {'αE':>10s}  {'αS':>10s}  {'αD':>10s}")
    print(f"  {'-'*120}")
    for _, r in result.iterrows():
        print(f"  {r['Material']:45s}  {r['ED_A']:7.2f}  {r['ED_B']:7.2f}"
              f"  {r['R2_A']:6.4f}  {r['R2_B']:6.4f}"
              f"  {r['alpha_E']:10.4f}  {r['alpha_S']:10.4f}  {r['alpha_D']:10.4f}")
# Out:
# ...
#   O2/N2:  2 materials for Arrhenius fitting
# ...
#   Material                                          ED_A     ED_B    R²_A    R²_B          αE          αS          αD
#   ------------------------------------------------------------------------------------------------------------------------
#   6FDA-DAM                                         16.74    19.23  0.9995  0.9998      2.7299      0.8893      2.4278
#   6FDA-PMDA-FDA                                    21.20    25.84  0.9936  0.9992      6.5073      0.6528      4.2483
#
# ...
#   CO2/N2:  8 materials for Arrhenius fitting
# ...
#   Material                                          ED_A     ED_B    R²_A    R²_B          αE          αS          αD
#   ------------------------------------------------------------------------------------------------------------------------
#   6FDA-DAM                                         13.80    19.23  0.9951  0.9998      8.9494      0.1795      1.6068
# ...

# %%
# %% CELL 5 — COLLECT PERMEABILITY DATA FOR ROBESON COORDINATES
"""
For each material that has selectivity decomposition (from any route),
find the permeability of the MORE permeable gas → Robeson x-axis,
and the permeability selectivity αP → Robeson y-axis.

Preference: use P at the reference temperature (25 °C), fallback to closest T.
"""

def get_permeability(material, gas, T_pref=25):
    """Get permeability [Barrer] for a material/gas, preferring T_pref."""
    rows = df[(df["Material"] == material) & (df["Gas"] == gas) & df["P_Barrer"].notna()]
    if len(rows) == 0:
        return np.nan, np.nan

    rows = rows.copy()
    rows["T_C"] = pd.to_numeric(rows["T_C"], errors="coerce")

    exact = rows[rows["T_C"] == T_pref]
    if len(exact) > 0:
        return exact["P_Barrer"].values[0], T_pref

    valid = rows[rows["T_C"].notna()].copy()
    if len(valid) > 0:
        valid["T_diff"] = (valid["T_C"] - T_pref).abs()
        best = valid.sort_values("T_diff").iloc[0]
        return best["P_Barrer"], best["T_C"]

    return rows["P_Barrer"].values[0], np.nan


robeson_data = {}

for pair, info in GAS_PAIRS.items():
    gasA, gasB = info["A"], info["B"]

    blocks = []

    if pair in existing and len(existing[pair]) > 0:
        blocks.append(existing[pair][["Material", "alpha_D", "alpha_E", "alpha_S", "source", "pair"]])

    if pair in from_ED and len(from_ED[pair]) > 0:
        blocks.append(from_ED[pair][["Material", "alpha_D", "alpha_E", "alpha_S", "source", "pair"]])

    if pair in arrhenius_results and len(arrhenius_results[pair]) > 0:
        blocks.append(arrhenius_results[pair][["Material", "alpha_D", "alpha_E", "alpha_S", "source", "pair"]])

    if len(blocks) == 0:
        robeson_data[pair] = pd.DataFrame()
        continue

    combined = pd.concat(blocks, ignore_index=True)
    combined = combined.drop_duplicates(subset="Material", keep="first")

    P_A_list, P_B_list, T_used_list = [], [], []
    for _, r in combined.iterrows():
        pA, tA = get_permeability(r["Material"], gasA)
        pB, tB = get_permeability(r["Material"], gasB)
        P_A_list.append(pA)
        P_B_list.append(pB)
        T_used_list.append(tA if pd.notna(tA) else tB)

    combined[f"P_{gasA}"] = P_A_list
    combined[f"P_{gasB}"] = P_B_list
    combined["T_P"] = T_used_list
    combined["alpha_P"] = combined[f"P_{gasA}"] / combined[f"P_{gasB}"]

    robeson_data[pair] = combined

    print(f"\n{'='*60}")
    print(f"  {pair}:  Robeson coordinates assembled")
    print(f"{'='*60}")

    has_full = combined[combined[f"P_{gasA}"].notna() & combined["alpha_E"].notna()]
    no_P = combined[combined[f"P_{gasA}"].isna()]

    print(f"  Total materials with αE/αS: {len(combined)}")
    print(f"  With permeability (Robeson-ready): {len(has_full)}")
    print(f"  Missing permeability: {len(no_P)}")
    if len(no_P) > 0:
        print(f"    → {list(no_P['Material'].values)}")
# Out:
# ...
#   O2/N2:  Robeson coordinates assembled
# ...
#   Total materials with αE/αS: 40
#   With permeability (Robeson-ready): 24
#   Missing permeability: 16
#     → ['6FDA-6FmDA', '6FDA-6FpDA', '6FDA-TAB', '6FDA-TADPO', '6FDA/PMDA(10/90)-TAB', '6FDA/PMDA(25/75)-TAB', '6FDA/PMDA(50/50)-TAB', 'AP', 'PC', 'PERY', 'TMPC', 'Zeolite 4A', 'Precursor (6FDA/DETDA:DABA)', '550°C-CMS', '800°C-CMS', '800°C-precrosslinked-CMS']
#
# ...
#   CO2/N2:  Robeson coordinates assembled
# ...
#   Total materials with αE/αS: 28
#   With permeability (Robeson-ready): 24
#   Missing permeability: 4
#     → ['Precursor (6FDA/DETDA:DABA)', '550°C-CMS', '800°C-CMS', '800°C-precrosslinked-CMS']
#
# ...
#   CO2/CH4:  Robeson coordinates assembled
# ...
#   Total materials with αE/αS: 30
#   With permeability (Robeson-ready): 23
#   Missing permeability: 7
#     → ['CMS (6FDA-DETDA:DABA 3:2/550°C)', 'CMS (6FDA-DETDA:DABA 3:2/800°C)', 'Y-fum-fcu-MOF/6FDA-DAM 20%', 'Precursor (6FDA/DETDA:DABA)', '550°C-CMS', '800°C-CMS', '800°C-precrosslinked-CMS']

# %%
# %% CELL 6 — FINAL ROBESON-READY DATASET
"""
Build the clean final dataframes: one per gas pair, containing only materials
with all required fields:
  - P_A (x-axis of Robeson plot, Barrer)
  - alpha_P (y-axis of Robeson plot)
  - alpha_E (colorbar: energetic selectivity)
  - alpha_S (colorbar: entropic selectivity)

Print the complete table for each pair.
"""

final = {}

print(f"\n{'#'*70}")
print(f"  FINAL ROBESON-READY DATASETS")
print(f"{'#'*70}")

for pair, info in GAS_PAIRS.items():
    gasA, gasB = info["A"], info["B"]

    if pair not in robeson_data or len(robeson_data[pair]) == 0:
        print(f"\n  {pair}: NO DATA")
        final[pair] = pd.DataFrame()
        continue

    rdata = robeson_data[pair].copy()
    ready = rdata[
        rdata[f"P_{gasA}"].notna() &
        rdata[f"P_{gasB}"].notna() &
        rdata["alpha_E"].notna() &
        rdata["alpha_S"].notna()
    ].copy()

    ready = ready.sort_values(f"P_{gasA}", ascending=False).reset_index(drop=True)
    final[pair] = ready

    print(f"\n{'='*60}")
    print(f"  {pair}:  {len(ready)} materials ready for Robeson plot")
    print(f"{'='*60}")
    print(f"  {'#':>3s}  {'Material':40s}  {'P('+gasA+')':>10s}  {'αP':>8s}  {'αD':>8s}  {'αE':>10s}  {'αS':>10s}  {'source':>12s}")
    print(f"  {'-'*140}")
    for i, (_, r) in enumerate(ready.iterrows()):
        aD = f"{r['alpha_D']:.3f}" if pd.notna(r["alpha_D"]) else "—"
        print(f"  {i+1:3d}  {r['Material']:40s}  {r[f'P_{gasA}']:10.1f}  {r['alpha_P']:8.2f}"
              f"  {aD:>8s}  {r['alpha_E']:10.4f}  {r['alpha_S']:10.4f}  {r['source']:>12s}")
# Out:
# ######################################################################
#   FINAL ROBESON-READY DATASETS
# ######################################################################
#
# ...
#   O2/N2:  24 materials ready for Robeson plot
# ...
#     #  Material                                       P(O2)        αP        αD          αE          αS        source
#   --------------------------------------------------------------------------------------------------------------------------------------------
#     1  PIM-SBI-Trip                                  6390.0      2.76     4.720    716.0000      0.0070      existing
#     2  PIM-SBI-Trip-co_PIM-1                         4230.0      3.26     4.220    188.0000      0.0250      existing
#     3  DBPI-550                                      3267.0      7.21     3.060    416.0000      0.0074      existing
#     4  PTMSP                                         3000.0      1.67     1.333      1.0000      1.3333       from_ED
# ...

# %%
# %% CELL 7 — DIAGNOSTIC: SELECTIVITY DECOMPOSITION CONSISTENCY CHECK
"""
Verify internal consistency:  αD ≈ αE × αS  for all data points.
Flag any materials where the product deviates significantly from αD.
Also check for physically suspect values (αE or αS < 0, extreme outliers).
"""

print(f"\n{'#'*70}")
print(f"  CONSISTENCY CHECK: αD vs αE × αS")
print(f"{'#'*70}")

for pair, info in GAS_PAIRS.items():
    ready = final[pair]
    if len(ready) == 0:
        continue

    check = ready[ready["alpha_D"].notna()].copy()
    check["alpha_D_calc"] = check["alpha_E"] * check["alpha_S"]
    check["rel_error"] = ((check["alpha_D_calc"] - check["alpha_D"]) / check["alpha_D"]).abs()

    print(f"\n  {pair}:")
    flagged = check[check["rel_error"] > 0.05]
    if len(flagged) == 0:
        print(f"    ✅ All {len(check)} materials pass (|error| < 5%)")
    else:
        print(f"    ⚠️  {len(flagged)} materials with |error| > 5%:")
        for _, r in flagged.iterrows():
            print(f"      {r['Material']:40s}  αD={r['alpha_D']:.3f}  αE×αS={r['alpha_D_calc']:.3f}  err={r['rel_error']:.1%}")

    suspects = ready[(ready["alpha_E"] < 0) | (ready["alpha_S"] < 0)]
    if len(suspects) > 0:
        print(f"    🔴 Negative values found:")
        for _, r in suspects.iterrows():
            print(f"      {r['Material']:40s}  αE={r['alpha_E']:.4f}  αS={r['alpha_S']:.4f}")
# Out:
# ######################################################################
#   CONSISTENCY CHECK: αD vs αE × αS
# ######################################################################
#
#   O2/N2:
#     ⚠️  8 materials with |error| > 5%:
#       PIM-SBI-Trip                              αD=4.720  αE×αS=5.012  err=6.2%
#       PIM-SBI-Trip-co_PIM-1                     αD=4.220  αE×αS=4.700  err=11.4%
#       PIM-1                                     αD=2.930  αE×αS=3.227  err=10.2%
#       Matrimid + Trip-H_20                      αD=3.020  αE×αS=3.341  err=10.6%
#       Matrimid + Trip-NO2_20                    αD=4.010  αE×αS=4.444  err=10.8%
#       Matrimid + Trip-NH2_20                    αD=4.340  αE×αS=4.805  err=10.7%
#       Matrimid + Trip-SO3H_20                   αD=2.240  αE×αS=2.484  err=10.9%
#       Matrimid                                  αD=3.080  αE×αS=3.434  err=11.5%
#
#   CO2/N2:
#     ✅ All 18 materials pass (|error| < 5%)
#
#   CO2/CH4:
# ...

# %%
# %% CELL 8 — OVERVIEW VISUALIZATION: αE vs αS SCATTER
"""
Quick diagnostic scatter: log(αE) vs log(αS) colored by source, one panel per pair.
This shows at a glance whether the decomposition produces physically reasonable
values and whether different data sources are consistent.
"""

fig, axes = plt.subplots(1, 3, figsize=(15, 4.5))

source_colors = {"existing": "#2196F3", "from_ED": "#4CAF50", "arrhenius": "#E91E63"}
source_markers = {"existing": "o", "from_ED": "D", "arrhenius": "s"}

for ax, (pair, info) in zip(axes, GAS_PAIRS.items()):
    ready = final[pair]
    if len(ready) == 0:
        ax.set_title(f"{GAS_PAIRS[pair]['label']}\n(no data)", fontsize=11, fontweight="bold")
        ax.text(0.5, 0.5, "No data", ha="center", va="center", transform=ax.transAxes)
        continue

    for src in ["existing", "from_ED", "arrhenius"]:
        sub = ready[ready["source"] == src]
        if len(sub) == 0:
            continue
        ax.scatter(
            sub["alpha_E"], sub["alpha_S"],
            c=source_colors[src], marker=source_markers[src],
            s=50, alpha=0.8, edgecolors="white", linewidth=0.5,
            label=f"{src} ({len(sub)})", zorder=3,
        )

    ax.axhline(1, color="#999", ls=":", lw=0.8, zorder=1)
    ax.axvline(1, color="#999", ls=":", lw=0.8, zorder=1)
    ax.set_xscale("log")
    ax.set_yscale("log")
    ax.set_xlabel(r"$\alpha_E$ (energetic selectivity)", fontsize=10)
    ax.set_ylabel(r"$\alpha_S$ (entropic selectivity)", fontsize=10)
    ax.set_title(f"{GAS_PAIRS[pair]['label']}", fontsize=12, fontweight="bold")
    ax.legend(fontsize=8, framealpha=0.8)

plt.tight_layout()
plt.show()

# %%
# %% CELL 9 — FINAL SUMMARY
"""
Print the grand summary: how many materials are available for each Robeson plot
and where the data came from.
"""

print(f"\n{'#'*70}")
print(f"  GRAND SUMMARY")
print(f"{'#'*70}")
print(f"\n  Reference temperature for αE: {T_REF - 273.15:.0f} °C ({T_REF:.2f} K)")
print(f"\n  {'Gas Pair':>10s}  {'Total':>6s}  {'existing':>10s}  {'from_ED':>10s}  {'arrhenius':>10s}")
print(f"  {'-'*55}")

for pair, info in GAS_PAIRS.items():
    ready = final[pair]
    n_total = len(ready)
    n_existing = len(ready[ready["source"] == "existing"])
    n_ed = len(ready[ready["source"] == "from_ED"])
    n_arr = len(ready[ready["source"] == "arrhenius"])
    print(f"  {pair:>10s}  {n_total:6d}  {n_existing:10d}  {n_ed:10d}  {n_arr:10d}")

print(f"\n  Materials ready for Robeson plot with energetic/entropic color mapping.")
print(f"  The 'final' dictionary contains one DataFrame per gas pair.")
# Out:
# ######################################################################
#   GRAND SUMMARY
# ######################################################################
#
#   Reference temperature for αE: 25 °C (298.15 K)
#
#     Gas Pair   Total    existing     from_ED   arrhenius
#   -------------------------------------------------------
#        O2/N2      24          20           2           2
#       CO2/N2      24          14           2           8
#      CO2/CH4      20           0          14           6
#
#   Materials ready for Robeson plot with energetic/entropic color mapping.
#   The 'final' dictionary contains one DataFrame per gas pair.
